# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Create a database which can be accessed by all the nodes

# %%
DB = {} #database
B = 20 #MHz; bandwidth of each block

M = 10 #number of f-blocks
# density = 125e-6
# N = 25 #number of nodes
# area = N/density
# L = np.sqrt(area)

d_max = 100 #m; max distance between two neighbors
d_min = 10 #m; nodes are not allowed to be closer than 10m
epsilon = -1e-5
alpha = 2.5 #pathloss exponent
noise = 1e-5 #W; Rx noise
P = 0.1 #W; Tx power of each access point
R = 30.0 #m; range of an access point
N_ITER = 100

# %% [markdown]
# Importing Glasgow Data

# %%
data_full = pd.read_csv("./data/glasgow_xy.csv")

# %%
x_lower = -500
x_upper = 500
y_lower = -500
y_upper = 500

data = data_full.loc[(data_full['X'] > x_lower) & (data_full['X'] < x_upper) & \
                     (data_full['Y'] > y_lower) & (data_full['Y'] < y_upper)]
N = len(data.index)
print(N)
# Out:
# 2410

# %% [markdown]
# Channel Gain matrix

# %%
H = np.random.exponential(1, (N, N))

for i in range(N):
  for j in range(N):
    H[i][j] = H[j][i]

# %% [markdown]
# Define a class for nodes

# %%
class Node:
  def __init__(self, x, y, ID):
    self.x = x
    self.y = y
    self.ID = str(ID)
    self.neighbors = {}
    self.neighbor_nodes = []
    self.BSI = None
    self.datarate_min = None

  def init_BSI(self):
    self.BSI = np.ones(M, dtype='float64')

  def publish_BSI(self):
    DB[self.ID] = self.BSI

  def add_neighbor(self, ID, distance):
    self.neighbors[str(ID)] = distance
    self.neighbor_nodes.append(ID)

  def update_BSI(self):
    # collect the BSI of neighbors and scale them by 1/distance^2
    score = np.zeros(M, dtype='float64')
    for nn in self.neighbor_nodes:
      # suggestion from the neighbours
      this_BSI = -np.power(max(1,self.neighbors[str(nn)]), -alpha)*DB[str(nn)]
      score = score + this_BSI
    # print(score)
    
    
    # update the BSI by occupying the positive scores
    not_chosen = []

    # social learning
    for m in range(M):
      if score[m] > epsilon:
        self.BSI[m] = 1.0
      else:
        self.BSI[m] = -1.0
        not_chosen.append(m)
    
    # check if the datarate requirements are satisfied:
    # by calculating the performance in each f-block
    self.publish_BSI()
    datarate_achieved = get_datarate(int(self.ID))

    # self learning
    while len(not_chosen) > 2: 
      if datarate_achieved >= self.min_datarate:
        break

      k_max = not_chosen[np.random.randint(len(not_chosen))]
      self.BSI[k_max] = 1.0
      not_chosen.remove(k_max)

      self.publish_BSI()
      datarate_achieved = get_datarate(int(self.ID))


    self.publish_BSI()

# %% [markdown]
# Create Nodes

# %%
node_list = []
X = list(data['X'])
Y = list(data['Y'])

for i in range(N):
    node_list.append(Node(X[i], Y[i], i))

# %% [markdown]
# Neighbors

# %%
def distance(i, j):
    x_i = node_list[i].x
    y_i = node_list[i].y
    x_j = node_list[j].x
    y_j = node_list[j].y
    
    return np.sqrt( np.square(x_i-x_j) + np.square(y_i-y_j) )


i = 0
while i<N:
    j = i+1
    while j< N:
        d_ij = distance(i,j)
        if d_ij < d_min:
            node_list.remove(node_list[j])
            j-=1
        N = len(node_list)
        j+=1
    N = len(node_list)
    i+=1


for i in range(N):
    node_list[i].ID = str(i)

for i in range(N):
    for j in range(i+1, N):
        d = distance(i, j)
        if d < d_max:
            node_list[i].add_neighbor(j, d)
            node_list[j].add_neighbor(i, d)

# %%
print(N)
# Out:
# 415

# %% [markdown]
# Visualize nodes

# %%
plt.figure(figsize=(10, 10), dpi=200)
for i in range(N):
    for j in node_list[i].neighbor_nodes:
        plt.plot([node_list[i].x, node_list[j].x], [node_list[i].y, node_list[j].y], color='black', linewidth=0.1)

for i in range(N):
  plt.scatter(node_list[i].x, node_list[i].y, color='red', s=10)

plt.grid()
plt.show()

# %% [markdown]
# Initialize BSI for all nodes

# %%
for i in range(N):
  node_list[i].init_BSI()
  node_list[i].publish_BSI()

# %% [markdown]
# Performance Evaluation

# %%
def get_datarates(opt):
  datarate = np.zeros(N, dtype='float64')
  SE = np.zeros(N, dtype='float64') # average spectral efficiency
  n_iter = 1000

  for iter in range(n_iter):
    H = np.random.exponential(1, (N, N))

    for i in range(N):
      for j in range(N):
        H[i][j] = H[j][i] 
    
    for i in range(N):
      BSI_i = node_list[i].BSI
      c = 0
      for m in range(M):
        if BSI_i[m] > 0:
          I_power = 0.0
          for j in range(N):
            if j!=i:
              if node_list[j].BSI[m] > 0:
                d = distance(i, j)
                I_power += H[i][j]*P*np.power(max(1.0,d), -alpha)
          
          SINR = H[i][i]*P*np.power(max(1.0,R), -alpha)/(noise + I_power)
          datarate[i] += B*np.log2(1 + SINR) 
          c += 1
          SE[i] += datarate[i]/(c*B)
    

  if opt:
    return datarate/n_iter
  return SE/n_iter

def get_datarate(i):
  datarate = 0.0
  BSI_i = node_list[i].BSI
  for m in range(M):
    if BSI_i[m] > 0:
      I_power = 0.0
      for j in range(N):
        if j!=i:
          if node_list[j].BSI[m] > 0:
            d = distance(i, j)
            I_power += P*np.power(max(1.0,d), -alpha)
      SINR = P*np.power(max(1.0,R), -alpha)/(noise + I_power)
      datarate += B*np.log2(1 + SINR)

  return datarate


def get_datarates_all(opt):
  n_iter = N_ITER
  datarate = np.zeros((N, n_iter), dtype='float64')
  SE = np.zeros((N, n_iter), dtype='float64')

  for iter in range(n_iter):
    H = np.random.exponential(1, (N, N))

    for i in range(N):
      for j in range(N):
        H[i][j] = H[j][i] 
    
    for i in range(N):
      BSI_i = node_list[i].BSI
      c = 0
      for m in range(M):
        if BSI_i[m] > 0:
          I_power = 0.0
          for j in range(N):
            if j!=i:
              if node_list[j].BSI[m] > 0:
                d = distance(i, j)
                I_power += H[i][j]*P*np.power(max(1.0,d), -alpha)
          
          SINR = H[i][i]*P*np.power(max(1.0,R), -alpha)/(noise + I_power)
          datarate[i][iter] += B*np.log2(1 + SINR)
          c+= 1 
      SE[i][iter] += datarate[i][iter]/(c*B)
    
  if opt:
    return SE

  return datarate

# %% [markdown]
# Set minimum datarate values for each node

# %%
for i in range(N):
  node_list[i].min_datarate = get_datarate(i)

# %% [markdown]
# Create a sequence (Poisson clock)

# %%
poisson_triggers = list(np.random.randint(N, size=20*N))

# %%
D_init_hist = get_datarates_all(0)
# SE_init_hist = get_datarates_all(1)

# %%
for i in poisson_triggers:
  node_list[i].update_BSI()

# %%
D_final_hist = get_datarates_all(0)
# SE_final_hist = get_datarates_all(1)

# %% [markdown]
# ### Save data

# %%
# np.savetxt("D_init_"+str(N)+".csv", D_init_hist, delimiter=",")
# np.savetxt("D_final_"+str(N)+".csv", D_final_hist, delimiter=",")
# np.savetxt("SE_init_"+str(N)+".csv", SE_init_hist, delimiter=",")
# np.savetxt("SE_final_"+str(N)+".csv", SE_final_hist, delimiter=",")

# %% [markdown]
# Plots

# %%
plt.figure(figsize=(10, 3), dpi=200)
plt.plot(list(range(N)), np.mean(D_init_hist, axis=1), color='blue', label='init')
plt.plot(list(range(N)), np.mean(D_final_hist, axis=1), '--', color='red', label='final')
plt.xlabel('Node ID')
plt.ylabel('Datarate [Mbps]')
plt.legend()
plt.show()

# %%
# Jain's Fairness Index

J_fair_init = np.square(np.sum(np.mean(D_init_hist, axis=1)))/(N*np.sum(np.square(np.mean(D_init_hist, axis=1))))
J_fair_final = np.square(np.sum(np.mean(D_final_hist, axis=1)))/(N*np.sum(np.square(np.mean(D_final_hist, axis=1))))

print(J_fair_init, J_fair_final)
# Out:
# 0.5166730628454465 0.6000494869004316

# %%
plt.figure(figsize=(8, 5), dpi=200)
plt.hist(np.reshape(D_init_hist, (N*N_ITER, 1)), bins=100, density=True, cumulative=True, label='init', histtype='step', color='blue')
plt.hist(np.reshape(D_final_hist, (N*N_ITER, 1)), bins=100, density=True, cumulative=True, label='final', histtype='step', color='red')
plt.xlabel('Datarate [Mbps]')
plt.legend(loc='lower right')
plt.xlim(-0.5, 200)
plt.ylim(0.2, 1)
plt.grid()
plt.show()
